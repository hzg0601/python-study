# %%
#小规模,数据量小,爬取速度不敏感,request库,爬网页
#中规模,数据规模比较大,爬取速度敏感,scrapy库,爬取网站
#大规模,用于搜索引擎,只能定制开发,爬取全网

#网络爬虫的限制
#来源审查:判断User-Agent进行限制
    #检查来访HTTP协议头的User-Agent域,只响应浏览器或友好爬虫的访问,只允许浏览器访问
#发布公告,Robots协议
    #告知所有爬虫网站的爬取策略,要求爬虫遵守,但是否遵守仍取决于爬虫者
    #Robots Exclusive Standard 网络爬虫排除标准
    #形式:在网站根目录下放置robots.txt文件
    #https://www.jd.com/robots.txt
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
img=mpimg.imread('C:\\Users\\hzg0601\\Pictures\\QQ截图20180308121854.png')
plt.imshow(img)
plt.axis('off')
plt.show()    
    
 #user-agent:*,对于所有User-Agent都需遵守   
#Disallow:/?*,不允许访问以问号开头的域
#Disallow:/pop/*/html,不允许访问pop下的域
#Disallow:/pinpai/*.html?*
#不允许Etao/Huihui/Gwdang/Wochacha进行任何爬虫,/代表根目录


#如无Robots协议则允许无限制访问和爬虫

# %%
#网络爬虫:自动或人工识别robots.txt,再进行内容爬取
#约束性:Robots是建议而非约束性,可以不遵守,但存在法律风险
